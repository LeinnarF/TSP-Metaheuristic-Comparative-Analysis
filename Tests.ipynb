# %%
# %cd /content/drive/MyDrive/ColabNotebooks/GitHub/TSP-Metaheuristic-Comparative-Analysis
# Out:
# /content/drive/MyDrive/ColabNotebooks/GitHub/TSP-Metaheuristic-Comparative-Analysis

# %%
from GWO import GreyWolfTSP
import time
import numpy as np
import TSP_to_Graph as tsptg

# %%
graph = tsptg.turnToGraph("berlin52")

gwo = GreyWolfTSP(graph, num_wolves=5, max_iter=3, use_local_search=True, random_seed=12)
start = time.perf_counter()
output = gwo.optimize()[1]
end = time.perf_counter()

# %%
print(output)
print(end-start)
# Out:
# 7804.0
# 17.295807060999778

# %%
# !git switch jobranch
# Out:
# Already on 'jobranch'
